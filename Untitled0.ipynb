# %%
 
low=int(input ("enter start values:"))
 
high=int(input ("enter end value:"))
 
while low<=high:
      temp=low
      s=0
      c=0
      while temp!=0:
           c=c+1
           temp=int(temp/10)
      temp=low
      while temp!=0:
          rem=temp%10
          p=1
          for i in range(0,c):
               p=p*rem
          s=s+p
          temp=int(temp/10)
      if s==low:
         print(low)
         break
      low=low+1
# Out:
# enter start values:1042000
# enter end value:702648265
# 1741725

# %%
a=1042000
b=702648265
while a<=b:
      temp=a
      s=0
      c=0
      while temp!=0:
            c=c+1
            temp=int(temp/10)
      temp=a
      while temp!=0:
            rem=temp%10
            p=1
            for i in range(0,c):
                p=p*rem
            s=s+p
            temp=int(temp/10)
      if s==a:
         print(a)
         break
      a=a+1
# Out:
# 1741725

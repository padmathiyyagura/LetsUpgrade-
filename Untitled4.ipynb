# %% [markdown]
# Question_1

# %%
class bank_acount():
     def __init__(self, username, balance):
          self.username = username
          self.balance = balance
     def deposit(self):
         amount=int(input("enter amount to deposit:"))
         self.balance=self.balance + amount
         print("balance is",self.balance)
     def withdraw(self):
         amount=int(input("enter the amount to withdraw:"))
         if self.balance<amount:
            print("insufficient balance")
         else:
            self.balance=self.balance-amount
            print ("new balance is:",self.balance)

# %%
 Obj = bank_acount("padma",1000)

# %%
Obj.deposit()
# Out:
# enter amount to deposit:10000
# balance is 12000

# %%
Obj.withdraw()
# Out:
# enter the amount to withdraw:2000
# new balance is: 10000

# %% [markdown]
# Question_2

# %%
import math
class mensuration():
      PI=3.14
      def __init__(self,radius,height):
          self.radius = radius
          self.height = height
      def volume(self):
           volume=math.pi*self.radius**2
           Volume=self.height/3
           print (" volume is", volume)
      def surface(self):
          base=math.pi*self.radius**2
          side=math.pi*self.radius*math.sqrt((self.radius**2+self.height))
          print("base is:",base)
          print ("side is:",side)

# %%
Ob=mensuration(6,8)
Ob.volume()
Ob.surface()
# Out:
#  volume is 113.09733552923255
# base is: 113.09733552923255
# side is: 125.03380891313174
